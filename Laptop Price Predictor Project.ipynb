# %%
# Importing Libraries
import numpy as np
import pandas as pd

# %%
#Importing and loading the dataset
df=pd.read_csv('Laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
# Data Cleaning
df.duplicated().sum() #no two rows are identically same.
# Out:
# 0

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram']= df['Ram'].str.replace('GB','')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Weight']=df['Weight'].str.replace('kg','')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']= df['Weight'].astype('float32')
df['Price']=df['Price'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   int64
# dtypes: float32(1), float64(1), int32(1), int64(1), object(7)
# memory usage: 101.9+ KB

# %%
#Exploratory Data Analysis(Univariate+Bivariate)  
# Univariate Analysis--> x-df['price']
#Try to remove warning msg from here by doing import warnings = 'ignore'
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(df['Price']) #Data is skewed
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
#We want to investigate comapny wise laptop distribution plot
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# 1.Either remove all laptops data which do not have famous brand names.
# 2.Or keep all of them intact.
# We will decide between options 1 and 2 based on the relationship between company name and laptop price.
# If there is a strong correlation(direct proportionality) between laptop price and company name for not so famous laptops we choose 1 else 2.

# %%
#Now we want to know avg price of each of the brands
#This will prove whether Company column has effect on laptop prices or not.
sns.barplot(x=df['Company'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Price'>

# %%
#For clear names on x-axis it must be written vertically which removes ambiguity
#This comes in matplotlib so we have to import it
import matplotlib.pyplot as plt
# %matplotlib inline
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#From graph it seems quite significant that avg price of brand and popularity of brand plays a huge role in laptop prices.
#From customers point of view he/she can target HP,Acer,Asus.
# We finally chose option 1.

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Notebook sells the most among types which indicates people buy laptops in budget range especially students.

# %%
#Now we will check for Avg values for each of these types for better clarity.
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#Graph clearly shows that type of laptop also has a significant effect on prices.eg WORKSTATION are heavy duty laptops.

# %%
#Inches as density distribution plots
sns.distplot(df['Inches'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
# Most laptops sold comes in category of 15.6 inch,spike around 17 and 13-14
# Plotting scatterplot vs price for better clarity

# %%
sns.scatterplot(x=df['Inches'],y=df['Price']) #inches-->discrete/categorical
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
#There is not a very strong correlation between Prices and size.

# %%
#Screen Resolution
df['ScreenResolution'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#For better clarity
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
#1.Resolution is given for each one of them
#2.Whether it is IPS Panel or not
#3.Whether laptop is touch screen or not

# %%
#We will perform feature engineering for each laptop to check whether it is touchscreen or not and add a new column in data for this piece of information.
df['Touchscreen']= df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0
# ...

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches                  ScreenResolution  \
# 1023      HP   Notebook    14.0                 Full HD 1920x1080
# 1108      HP   Notebook    15.6                 Full HD 1920x1080
# 773     Dell     Gaming    15.6                 Full HD 1920x1080
# 921       HP  Ultrabook    15.6                 Full HD 1920x1080
# 1226    Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                               Cpu  Ram     Memory                      Gpu  \
# 1023   Intel Core i7 7500U 2.7GHz    8  256GB SSD     Nvidia GeForce 930MX
# 1108    AMD A6-Series 9220 2.5GHz    4    1TB HDD            AMD Radeon R4
# 773   Intel Core i7 7700HQ 2.8GHz    8    1TB HDD  Nvidia GeForce GTX 1050
# 921    Intel Core i7 6500U 2.5GHz    8  256GB SSD      AMD Radeon R7 M365X
# 1226   Intel Core i7 7500U 2.7GHz    8  256GB SSD    Intel HD Graphics 620
#
#            OpSys  Weight  Price  Touchscreen
# 1023  Windows 10    1.64  63159            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price']) #TouchScreen laptops have a higher price over non touchscreen ones.
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
# We will perform feature engineering for each laptop to check whether it has IPS Panel or not and add a new column in data for this piece of information.
df['Ips']= df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ips'],y=df['Price']) #Ips display has higher price over non ips displays.
# Out:
# <AxesSubplot:xlabel='Ips', ylabel='Price'>

# %%
#Now we will extract resolution information and make 2 separate columns for xres and yres.
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res']=new[0]
df['Y_res']=new[1]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# ...

# %%
# Regular expression in python
df['X_res']=df['X_res'].str.replace(',',' ').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   int64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(1), int32(1), int64(3), object(9)
# ...

# %%
df['X_res']=df['X_res'].astype('int32')
df['Y_res']=df['Y_res'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   int64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(1), int32(3), int64(3), object(7)
# ...

# %%
df.corr()['Price'] #Very important line of code,it shows how different columns are effecting the laptop prices and by what extent.
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252207
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
# Laptop prices have a strong correlation with X_res,Y_res and RAM
# we see that inches column is not very uesful to us because of its poor correlation
# Now we will make a new column called PPI(Pixels per inch) for which we will use X_res,Y_res and inches column.
# There is a multicollinearity between X_res and Y_res.

# %%
# PPI = SQRT(X_RES^2+Y_RES^2)/INCHES--->Formula for PPI calculation

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252207
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
#PPI has a strong correlation with price.
#Since we have extracted everything out of the screen resolution column we dont need it anymore.

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   47895
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37   96095
#
#    Touchscreen  Ips  X_res  Y_res         ppi
# 0            0    1   2560   1600  226.983005
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# 2  141.211998
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#Feature engineering needs to be done on cpu column as well.
# 118 different categories of cpu are available.

# %%
# So for our purpose we make 5 different categories for cpu processors
#I5,I7,I3,other intel processors, AMD

# %%
df['Cpu Name'] =  df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#           ppi       Cpu Name
# 0  226.983005  Intel Core i5
# ...

# %%
# We here create a function which will return the value of cpu name column if it is i3,i5,i7 else return according to conditions specified.
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)
df.sample(10)
# Out:
#       Company   TypeName                         Cpu  Ram     Memory  \
# 909        LG  Ultrabook  Intel Core i7 7500U 2.7GHz    8  512GB SSD
# 1113       HP  Ultrabook  Intel Core i7 6500U 2.5GHz    8  512GB SSD
# 120      Acer   Notebook  Intel Core i3 7100U 2.4GHz    6    1TB HDD
# 540      Dell  Ultrabook  Intel Core i7 8550U 1.8GHz    8  256GB SSD
# 1105     Dell  Ultrabook  Intel Core i5 6200U 2.3GHz    8  256GB SSD
# 947    Lenovo   Notebook  Intel Core i7 7500U 2.7GHz    8    1TB HDD
# 138    Lenovo   Notebook  Intel Core i5 7200U 2.5GHz    4    1TB HDD
# 844        HP  Ultrabook  Intel Core i7 6500U 2.5GHz    8  512GB SSD
# 43       Acer   Notebook  Intel Core i5 8250U 1.6GHz    4  256GB SSD
# 874   Samsung  Ultrabook  Intel Core i7 7500U 2.7GHz   16  256GB SSD
#
#                          Gpu       OpSys  Weight   Price  Touchscreen  Ips  \
# 909    Intel HD Graphics 620  Windows 10    0.98  101178            1    1
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Cpu brand vs price relationship
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Price has a strong correlation with processor.

# %%
#Since we have extacted everthing from cpu and cpu name columns its time to drop them.
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   71378            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095            0    1  226.983005  Intel Core i5

# %%
#RAM
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Strong(linear)realtionship between RAM and price thats why df.corr()['Price'] showed a value of 0.74
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#Memory
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# So for our purpose we make 4 different categories for Memory processors
# HDD,SSD,Flash Storage,Hybrid

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(5)
# Out:
#         Company   TypeName  Ram               Memory                      Gpu  \
# 605         MSI     Gaming   16  256 SSD +  2000 HDD  Nvidia GeForce GTX 1060
# 104   Microsoft  Ultrabook    8              256 SSD    Intel HD Graphics 620
# 562          HP  Ultrabook   16              512 SSD    Intel HD Graphics 515
# 1254       Dell   Notebook    4              500 HDD        Intel HD Graphics
# 1120       Vero   Notebook    4     32 Flash Storage    Intel HD Graphics 400
#
#              OpSys  Weight   Price  Touchscreen  Ips         ppi  \
# 605     Windows 10   1.800  122490            0    0  282.423996
# 104   Windows 10 S   1.252   71395            1    0  200.842560
# 562     Windows 10   1.160  104695            1    1  276.053530
# 1254    Windows 10   2.200   23655            0    0  100.454670
# 1120    Windows 10   1.350   10442            0    0  165.632118
#
#                   Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
#Now memory column should also be dropped.
df.drop(columns=['Memory'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  Hybrid  \
# 0   71378            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# ...

# %%
#Lets look at the price relationship with our newly added 4 columns.
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252207
# ppi              0.473487
# HDD             -0.096442
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
#There is a negative correlation between HDD vs price and Flash_Storage vs Price
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0   71378            0    1  226.983005  Intel Core i5    0  128
# 1   47895            0    0  127.677940  Intel Core i5    0    0
# 2   30636            0    0  141.211998  Intel Core i5    0  256
# 3  135195            0    1  220.534624  Intel Core i7    0  512
# 4   96095            0    1  226.983005  Intel Core i5    0  256

# %%
#GPU
df['Gpu'].value_counts()
# Here also 110 different categories.
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD Gpu brand
# 0   71378            0    1  226.983005  Intel Core i5    0  128     Intel
# 1   47895            0    0  127.677940  Intel Core i5    0    0     Intel
# 2   30636            0    0  141.211998  Intel Core i5    0  256     Intel
# 3  135195            0    1  220.534624  Intel Core i7    0  512       AMD
# 4   96095            0    1  226.983005  Intel Core i5    0  256     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM'] #Removing the ARM row.

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
#Relationship of GPU brand vs Price
sns.barplot(x=df['Gpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Median values shows the same trends,so no case of outliers.
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
#There is a strong relationship b/w Gpu brands and Price.
#Now Gpu Column should also be dropped.

# %%
df.drop(columns=['Gpu'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0    0
# 2      HP   Notebook    8  No OS    1.86   30636            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
#Opsys
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
#Relationship of OpSys vs Price
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# So for our purpose we make 3 different categories for OpSys
# Windows(7,10,10S..etc),MAC(OS,OS X),Others.

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0    0
# 2      HP   Notebook    8  No OS    1.86   30636            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
#Now OpsSys Column should also be dropped.
df.drop(columns=['OpSys'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram  Weight   Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#Weight
sns.distplot(df['Weight']) # Binodal(Laptops are usually sold in a range of 2)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
df.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253319
# ppi            0.475368
# HDD           -0.096892
# SSD            0.670660
# Name: Price, dtype: float64

# %%
df.corr() #Bivariate Analysis
# Out:
#                   Ram    Weight     Price  Touchscreen       Ips       ppi  \
# Ram          1.000000  0.383362  0.742905     0.118875  0.207949  0.305688
# Weight       0.383362  1.000000  0.209867    -0.293004  0.018643 -0.321883
# Price        0.742905  0.209867  1.000000     0.192917  0.253319  0.475368
# Touchscreen  0.118875 -0.293004  0.192917     1.000000  0.148026  0.458571
# Ips          0.207949  0.018643  0.253319     0.148026  1.000000  0.299142
# ppi          0.305688 -0.321883  0.475368     0.458571  0.299142  1.000000
# HDD          0.095808  0.514147 -0.096892    -0.208766 -0.093588 -0.294698
# SSD          0.603379 -0.063818  0.670660     0.257577  0.225311  0.509437
#
#                   HDD       SSD
# Ram          0.095808  0.603379
# Weight       0.514147 -0.063818
# Price       -0.096892  0.670660
# Touchscreen -0.208766  0.257577
# Ips         -0.093588  0.225311
# ppi         -0.294698  0.509437
# HDD          1.000000 -0.400750
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(np.log(df['Price']))# Our target column was pretty skewed so we applied log transformation in order to make it less skewed.
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
#This will not create much problems for our ML ALgorithms.

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175745
# 1       10.776766
# 2       10.329931
# 3       11.814473
# 4       11.473093
#           ...
# 1298    10.433880
# 1299    11.288106
# 1300     9.409273
# 1301    10.614106
# 1302     9.886341
# Name: Price, Length: 1302, dtype: float64

# %%
#Training our model
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
#The categorical columns needs to be handled separately.(Company,TypeName,Cpu brand,Gpu brand,os)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073285591703885
# MAE 0.21018098647453723

# %%
np.exp(0.21)
# Out:
# 1.2336780599567432

# %% [markdown]
# # Exporting The Model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight   Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378            0    1
# 1      Apple           Ultrabook    8    1.34   47895            0    0
# 2         HP            Notebook    8    1.86   30636            0    0
# 3      Apple           Ultrabook   16    1.83  135195            0    1
# 4      Apple           Ultrabook    8    1.37   96095            0    1
# ...      ...                 ...  ...     ...     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866            1    1
# 1300  Lenovo            Notebook    2    1.50   12201            0    0
# 1301      HP            Notebook    6    2.19   40705            0    0
# 1302    Asus            Notebook    4    2.20   19660            0    0
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# ...

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...
